# %%
import pandas as pd

from curate import curation as cur
from rdkit import Chem
# Out:
# *** CompoundDB module found. Will check the synonyms table to resolve CAS. ***

# %%
data_cur = cur.Curator()

# %%
smiles_df = pd.read_excel('sample_smiles.xlsx')

# %%
smiles_df.head()
# Out:
#    Unnamed: 0                          structure
# 0         131                      Cc1ccc(Cl)cc1
# 1         513                               NC#N
# 2          79                  Oc1ccc(Cl)c(Cl)c1
# 3         622      CC(c1ccccc1)c2ccc(OCCOCCO)cc2
# 4         736  O[P](O)(=O)c1cccc(c1)[N+]([O-])=O

# %%
for i, row in smiles_df.iterrows():
    smi = row['structure']
    sub_type, san_smi = data_cur.get_filtered_SMILES_and_substance_type(smi)
    smiles_df.ix[i,'structure_curated'] = san_smi
    smiles_df.ix[i,'substance_type_name'] = sub_type
# Out:
# /home/emarch/miniconda3/envs/inditex/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """
# /home/emarch/miniconda3/envs/inditex/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# RDKit ERROR: [13:09:18] Explicit valence for atom # 0 O, 4, is greater than permitted
# RDKit ERROR: [13:09:18] Explicit valence for atom # 2 O, 4, is greater than permitted
# RDKit ERROR: [13:09:18] Explicit valence for atom # 2 O, 4, is greater than permitted

# %%
smiles_df
# Out:
#     Unnamed: 0                                          structure  \
# 0          131                                      Cc1ccc(Cl)cc1
# 1          513                                               NC#N
# 2           79                                  Oc1ccc(Cl)c(Cl)c1
# 3          622                      CC(c1ccccc1)c2ccc(OCCOCCO)cc2
# 4          736                  O[P](O)(=O)c1cccc(c1)[N+]([O-])=O
# 5          785                                     CCCCCCCCCCOCCO
# 6          743                                           CN(C)CCO
# 7          804                                         [Cl-].[K+]
# 8          512                                [OH2--].[Cu+].[Cu+]
# 9          996            Clc1cc2oc3c(Cl)c(Cl)c(Cl)cc3c2c(Cl)c1Cl
# 10        1013                         Cc1cc(ccc1N)c2ccc(N)c(C)c2
# 11        1065  C1=CC(=CC=C1C2=CC=C(C=C2)N=NC3=C(C=C4C=C(C=CC4...
# 12         987           Clc1cc2Oc3c(Cl)c(Cl)c(Cl)c(Cl)c3Oc2cc1Cl
# 13        1159                      Cc1ccccc1N=Nc2c(N)ccc3ccccc23
# 14         455                                     CCCCOCCOC(C)=O
# 15         738                                        OCNC(=O)C=C
# 16         974                       O.[Zn++].[O-][S]([O-])(=O)=O
# 17         417                    [O--].[O--].[O--].[Sb+3].[Sb+3]
# 18        1049            COc1ccc(\C=C\C(=O)Nc2ccc(cc2)C(N)=O)cc1
# 19         695                                                 CO
#
#                                     structure_curated substance_type_name
# 0                                       Cc1ccc(Cl)cc1             organic
# 1                                                N#CN             organic
# 2                                   Oc1ccc(Cl)c(Cl)c1             organic
# 3                       CC(c1ccccc1)c1ccc(OCCOCCO)cc1             organic
# 4                     O=[N+]([O-])c1cccc(P(=O)(O)O)c1             organic
# 5                                      CCCCCCCCCCOCCO             organic
# 6                                            CN(C)CCO             organic
# 7                                          [Cl-].[K+]      inorganic_salt
# 8                                 [Cu+].[Cu+].[OH2-2]      inorganic_salt
# 9           Clc1cc2c(oc3cc(Cl)c(Cl)c(Cl)c32)c(Cl)c1Cl             organic
# 10                        Cc1cc(-c2ccc(N)c(C)c2)ccc1N             organic
# 11  Nc1ccc2c([O-])c(N=Nc3ccc(-c4ccc(N=Nc5c(S(=O)(=...        organic_salt
# 12         Clc1cc2c(cc1Cl)Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1O2             organic
# 13                      Cc1ccccc1N=Nc1c(N)ccc2ccccc12             organic
# 14                                     CCCCOCCOC(C)=O             organic
# 15                                        C=CC(=O)NCO             organic
# 16                         O.O=S(=O)([O-])[O-].[Zn+2]      inorganic_salt
# 17                    [O-2].[O-2].[O-2].[Sb+3].[Sb+3]      inorganic_salt
# 18            COc1ccc(/C=C/C(=O)Nc2ccc(C(N)=O)cc2)cc1             organic
# 19                                                 CO             organic

# %%
smiles_df.to_excel('smiles_curated.xlsx')
