# %%
import pandas as pd

from curate.chem import structure_curation as cur
from rdkit import Chem
# Out:
# [13:59:07] Initializing Normalizer

# %%
data_cur = cur.Curator()

# %%
smiles_df = pd.read_excel('sample_smiles.xlsx', engine='openpyxl')

# %%
smiles_df.head()
# Out:
#    name                          structure  meta1  meta2  meta3
# 0   131                      Cc1ccc(Cl)cc1  dummy  dummy  dummy
# 1   513                               NC#N  dummy  dummy  dummy
# 2    79                  Oc1ccc(Cl)c(Cl)c1  dummy  dummy  dummy
# 3   622      CC(c1ccccc1)c2ccc(OCCOCCO)cc2  dummy  dummy  dummy
# 4   736  O[P](O)(=O)c1cccc(c1)[N+]([O-])=O  dummy  dummy  dummy

# %%
for i, row in smiles_df.iterrows():
    smi = row['structure']
    data_cur.smiles_to_rdkit_mol(smi)
    substance_type, sanitized_smiles = data_cur.filter_smiles()   
    smiles_df.loc[smiles_df.index == i,'structure_curated'] = sanitized_smiles
    smiles_df.loc[smiles_df.index == i,'substance_type_name'] = substance_type
# Out:
# Valence error during salt removal: Explicit valence for atom # 0 O, 4, is greater than permitted
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: Cc1ccc(Cl)cc1
# [13:59:09] New largest fragment: Cc1ccc(Cl)cc1 (15)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: N#CN
# [13:59:09] New largest fragment: N#CN (5)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: Oc1ccc(Cl)c(Cl)c1
# [13:59:09] New largest fragment: Oc1ccc(Cl)c(Cl)c1 (13)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: CC(c1ccccc1)c1ccc(OCCOCCO)cc1
# [13:59:09] New largest fragment: CC(c1ccccc1)c1ccc(OCCOCCO)cc1 (43)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: O=[N+]([O-])c1cccc(P(=O)(O)O)c1
# [13:59:09] New largest fragment: O=[N+]([O-])c1cccc(P(=O)(O)O)c1 (19)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: CCCCCCCCCCOCCO
# [13:59:09] New largest fragment: CCCCCCCCCCOCCO (40)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: CN(C)CCO
# [13:59:09] New largest fragment: CN(C)CCO (17)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: [K+]
# [13:59:09] New largest fragment: [K+] (1)
# [13:59:09] Fragment: [Cl-]
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Explicit valence for atom # 0 O, 4, is greater than permitted
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Explicit valence for atom # 0 O, 4, is greater than permitted
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: Clc1cc2c(oc3cc(Cl)c(Cl)c(Cl)c32)c(Cl)c1Cl
# [13:59:09] New largest fragment: Clc1cc2c(oc3cc(Cl)c(Cl)c(Cl)c32)c(Cl)c1Cl (21)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: Cc1cc(-c2ccc(N)c(C)c2)ccc1N
# [13:59:09] New largest fragment: Cc1cc(-c2ccc(N)c(C)c2)ccc1N (32)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: [Na+]
# [13:59:09] New largest fragment: [Na+] (1)
# [13:59:09] Fragment: Nc1ccc2c([O-])c(N=Nc3ccc(-c4ccc(N=Nc5c(S(=O)(=O)O)cc6cc(N)ccc6c5[O-])cc4)cc3)c(S(=O)(=O)O)cc2c1
# [13:59:09] New largest fragment: Nc1ccc2c([O-])c(N=Nc3ccc(-c4ccc(N=Nc5c(S(=O)(=O)O)cc6cc(N)ccc6c5[O-])cc4)cc3)c(S(=O)(=O)O)cc2c1 (70)
# [13:59:09] Fragment: [Na+]
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Removed negative charge.
# [13:59:09] Removed negative charge.
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: Clc1cc2c(cc1Cl)Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1O2
# [13:59:09] New largest fragment: Clc1cc2c(cc1Cl)Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1O2 (22)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: Cc1ccccc1N=Nc1c(N)ccc2ccccc12
# [13:59:09] New largest fragment: Cc1ccccc1N=Nc1c(N)ccc2ccccc12 (35)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: CCCCOCCOC(C)=O
# [13:59:09] New largest fragment: CCCCOCCOC(C)=O (27)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: C=CC(=O)NCO
# [13:59:09] New largest fragment: C=CC(=O)NCO (14)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: O=S(=O)([O-])[O-]
# [13:59:09] New largest fragment: O=S(=O)([O-])[O-] (5)
# [13:59:09] Fragment: O
# [13:59:09] Fragment: [Zn+2]
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Removed negative charge.
# [13:59:09] Removed negative charge.
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: [O-2]
# [13:59:09] New largest fragment: [O-2] (1)
# [13:59:09] Fragment: [O-2]
# [13:59:09] New largest fragment: [O-2] (1)
# [13:59:09] Fragment: [O-2]
# [13:59:09] New largest fragment: [O-2] (1)
# [13:59:09] Fragment: [Sb+3]
# [13:59:09] New largest fragment: [Sb+3] (1)
# [13:59:09] Fragment: [Sb+3]
# [13:59:09] New largest fragment: [Sb+3] (1)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: COc1ccc(/C=C/C(=O)Nc2ccc(C(N)=O)cc2)cc1
# [13:59:09] New largest fragment: COc1ccc(/C=C/C(=O)Nc2ccc(C(N)=O)cc2)cc1 (38)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger
# [13:59:09] Running LargestFragmentChooser
# [13:59:09] Fragment: CO
# [13:59:09] New largest fragment: CO (6)
# [13:59:09] Running Normalizer
# [13:59:09] Running Uncharger

# %%
smiles_df
# Out:
#     name                                          structure  meta1  meta2  \
# 0    131                                      Cc1ccc(Cl)cc1  dummy  dummy
# 1    513                                               NC#N  dummy  dummy
# 2     79                                  Oc1ccc(Cl)c(Cl)c1  dummy  dummy
# 3    622                      CC(c1ccccc1)c2ccc(OCCOCCO)cc2  dummy  dummy
# 4    736                  O[P](O)(=O)c1cccc(c1)[N+]([O-])=O  dummy  dummy
# 5    785                                     CCCCCCCCCCOCCO  dummy  dummy
# 6    743                                           CN(C)CCO  dummy  dummy
# 7    804                                         [Cl-].[K+]  dummy  dummy
# 8    512                                [OH2--].[Cu+].[Cu+]  dummy  dummy
# 9    996            Clc1cc2oc3c(Cl)c(Cl)c(Cl)cc3c2c(Cl)c1Cl  dummy  dummy
# 10  1013                         Cc1cc(ccc1N)c2ccc(N)c(C)c2  dummy  dummy
# 11  1065  C1=CC(=CC=C1C2=CC=C(C=C2)N=NC3=C(C=C4C=C(C=CC4...  dummy  dummy
# 12   987           Clc1cc2Oc3c(Cl)c(Cl)c(Cl)c(Cl)c3Oc2cc1Cl  dummy  dummy
# 13  1159                      Cc1ccccc1N=Nc2c(N)ccc3ccccc23  dummy  dummy
# 14   455                                     CCCCOCCOC(C)=O  dummy  dummy
# 15   738                                        OCNC(=O)C=C  dummy  dummy
# 16   974                       O.[Zn++].[O-][S]([O-])(=O)=O  dummy  dummy
# 17   417                    [O--].[O--].[O--].[Sb+3].[Sb+3]  dummy  dummy
# 18  1049            COc1ccc(\C=C\C(=O)Nc2ccc(cc2)C(N)=O)cc1  dummy  dummy
# 19   695                                                 CO  dummy  dummy
#
#     meta3                                  structure_curated  \
# 0   dummy                                      Cc1ccc(Cl)cc1
# 1   dummy                                               N#CN
# 2   dummy                                  Oc1ccc(Cl)c(Cl)c1
# 3   dummy                      CC(c1ccccc1)c1ccc(OCCOCCO)cc1
# 4   dummy                    O=[N+]([O-])c1cccc(P(=O)(O)O)c1
# 5   dummy                                     CCCCCCCCCCOCCO
# 6   dummy                                           CN(C)CCO
# 7   dummy                                               [K+]
# 8   dummy                                               None
# 9   dummy          Clc1cc2c(oc3cc(Cl)c(Cl)c(Cl)c32)c(Cl)c1Cl
# 10  dummy                        Cc1cc(-c2ccc(N)c(C)c2)ccc1N
# 11  dummy  Nc1ccc2c(O)c(N=Nc3ccc(-c4ccc(N=Nc5c(S(=O)(=O)O...
# 12  dummy         Clc1cc2c(cc1Cl)Oc1c(Cl)c(Cl)c(Cl)c(Cl)c1O2
# 13  dummy                      Cc1ccccc1N=Nc1c(N)ccc2ccccc12
# 14  dummy                                     CCCCOCCOC(C)=O
# 15  dummy                                        C=CC(=O)NCO
# 16  dummy                                        O=S(=O)(O)O
# 17  dummy                                             [Sb+3]
# 18  dummy            COc1ccc(/C=C/C(=O)Nc2ccc(C(N)=O)cc2)cc1
# 19  dummy                                                 CO
#
#    substance_type_name
# 0              organic
# 1              organic
# 2              organic
# 3              organic
# 4              organic
# 5              organic
# 6              organic
# 7       inorganic_salt
# 8       no_sanitizable
# 9              organic
# 10             organic
# 11        organic_salt
# 12             organic
# 13             organic
# 14             organic
# 15             organic
# 16      inorganic_salt
# 17      inorganic_salt
# 18             organic
# 19           inorganic

# %%
smiles_df.to_excel('smiles_curated.xlsx')
